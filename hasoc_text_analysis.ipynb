# %% [markdown]
# # INTRODUCTION
# This project focuses on cleaning and analyzing social media text data to identify patterns related to hate speech using basic text processing techniques.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("en_Hasoc2021_train.csv")
df.head(29)
# Out:
#     Unnamed: 0                       _id  \
# 0         4986  60c5d6bf5659ea5e55defa2c
# 1         3394  60c5d6bf5659ea5e55def461
# 2         1310  60c5d6bf5659ea5e55defaad
# 3         3390  60c5d6bf5659ea5e55def419
# 4         4626  60c5d6bf5659ea5e55def7fa
# 5         1506  60c5d6bf5659ea5e55defc58
# 6         2298  60c5d6bf5659ea5e55df0132
# 7          309  60c5d6bf5659ea5e55def378
# 8         3582  60c5d6bf5659ea5e55def54f
# 9         2139  60c5d6bf5659ea5e55df0086
# 10         636  60c5d6bf5659ea5e55def5f7
# 11         150  60c5d6bf5659ea5e55def132
# 12        3586  60c5d6bf5659ea5e55def5dc
# 13         488  60c5d6bf5659ea5e55def33b
# 14          12  60c5d6bf5659ea5e55def204
# 15        4458  60c5d6bf5659ea5e55defe30
# 16        2875  60c5d6bf5659ea5e55def23a
# 17        4412  60c5d6bf5659ea5e55defd5d
# 18        2965  60c5d6bf5659ea5e55df00ca
# 19         208  60c5d6bf5659ea5e55def27d
# 20        2482  60c5d6bf5659ea5e55df016c
# 21         251  60c5d6bf5659ea5e55def19f
# 22        2050  60c5d6bf5659ea5e55df0014
# 23        3585  60c5d6bf5659ea5e55def5b8
# 24        1743  60c5d6bf5659ea5e55defe6f
# 25        3751  60c5d6bf5659ea5e55deff72
# 26        4122  60c5d6bf5659ea5e55defbf5
# 27         910  60c5d6bf5659ea5e55def8c1
# 28        3487  60c5d6bf5659ea5e55def3c1
#
#                                                  text task_1 task_2
# 0   @wealth if you made it through this &amp;&amp;...    HOF   PRFN
# 1   Technically that's still turning back the cloc...    HOF   OFFN
# 2   @VMBJP @BJP4Bengal @BJP4India @narendramodi @J...    NOT   NONE
# 3   @krtoprak_yigit Soldier of Japan Who has dick ...    HOF   OFFN
# 4   @blueheartedly You'd be better off asking who ...    HOF   OFFN
# 5                                    @ilyhiguchi DICK    HOF   PRFN
# 6   Why to blame only Modi or Government for this ...    NOT   NONE
# 7   The report on @TheLeadCNN that @clarissaward f...    NOT   NONE
# 8   @Chahal_Shekhar Sorry we won't, why can't your...    HOF   HATE
# 9   People are dying even in villages where there'...    NOT   NONE
# 10  It is disappointing to see Ohio will give init...    NOT   NONE
# 11  @narendramodi, you are #NotMyPrimeMinister any...    HOF   OFFN
# 12  Muslims should help cremate their dead because...    HOF   OFFN
# 13  yeah when she's finally done w you you wanna p...    HOF   PRFN
# 14  The situation all around us is extremely painf...    NOT   NONE
# 15  @AjeebBharti @BeraJaykrishna @khan_nainam @Pol...    HOF   PRFN
# 16  now i canât even get my tattoos bc this man ...    HOF   PRFN
# 17  Found the little bastard ðŸ‘Œ now the fun begi...    HOF   PRFN
# 18  This is just so heartbreaking ð­  Can't even...    NOT   NONE
# 19                   @dxnprivv Stop being a twat then    HOF   OFFN
# 20  One thing I can’t stand is people talking out ...    HOF   PRFN
# 21  Y’all. This is NOT it. Please give real help o...    NOT   NONE
# 22  It's heartbreaking to see Osama struggling alo...    NOT   NONE
# 23  @SubhashiniAli @PoojaB1972 Wah @narendramodi ,...    HOF   HATE
# 24  i’m tired of making other people comfortable w...    HOF   PRFN
# 25                 BITCH WHAT https://t.co/wdQRCTNzYn    HOF   OFFN
# 26  If you donâ€™t give a damn then I donâ€™t give...    HOF   PRFN
# 27  @timesofindia Panem et circenses. Distract the...    HOF   OFFN
# 28  @UtdEIIis Really like how this list started wi...    HOF   PRFN

# %% [markdown]
# ## Dataset Overview

# %%
df.shape                     #Shape of the dataset
df.info()                    #Column description
df['task_1'].value_counts()  #Target variable distribution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3843 entries, 0 to 3842
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3843 non-null   int64
#  1   _id         3843 non-null   object
#  2   text        3843 non-null   object
#  3   task_1      3843 non-null   object
#  4   task_2      3843 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 150.2+ KB
# task_1
# HOF    2501
# NOT    1342
# Name: count, dtype: int64

# %% [markdown]
# # DATA CLEANING

# %%
def clean_text(text):
    text = text.lower()                     # lowercase
    text = re.sub(r"http\S+", "", text)     # remove URLs
    text = re.sub(r"[^a-z\s]", "", text)    # remove special characters
    return text

clean_text('@30iPpgStmILw0SI @ChinaDaily #ChineseVirus #Wu...')

#why clean text? Because: URLs = useless,Special symbols = noise,Capital letters = inconsistent
# Out:
# 'ippgstmilwsi chinadaily chinesevirus wu'

# %% [markdown]
# ## Apply Cleaning

# %%
df['clean_text'] = df['text'].apply(clean_text)
df['clean_text']

# why used = It cleans every text row one by one and saves the cleaned text in a new column.
# Out:
# 0       wealth if you made it through this ampamp were...
# 1       technically thats still turning back the clock...
# 2       vmbjp bjpbengal bjpindia narendramodi jpnadda ...
# 3        krtoprakyigit soldier of japan who has dick head
# 4       blueheartedly youd be better off asking who do...
#                               ...
# 3838    bbcnews let the dog deal with the wanker once ...
# 3839    india has suffered a lot that chinese bastard ...
# 3840    people didnt give  seats majority to bjp to se...
# 3841    kanganateam this is such a vile xenophobic and...
# 3842    ippgstmilwsi chinadaily chinesevirus wuhanviru...
# Name: clean_text, Length: 3843, dtype: object

# %% [markdown]
# # CREATE SIMPLE FEATURES

# %% [markdown]
# ## 1. Text Length

# %%
df['text_length'] = df['clean_text'].apply(len)
df['text_length'].head(29)

#This creates a new column that stores the total number of characters in each cleaned text.
# Out:
# 0     204
# 1      57
# 2     316
# 3      48
# 4      82
# 5      15
# 6     163
# 7     235
# 8     242
# 9     270
# 10    233
# 11    228
# 12    271
# 13     75
# 14    265
# 15    107
# 16     67
# 17     46
# 18    264
# 19     31
# 20     78
# 21    106
# 22    239
# 23    235
# 24     99
# 25     11
# 26     48
# 27    230
# 28     59
# Name: text_length, dtype: int64

# %% [markdown]
# ## 2. Word Count

# %%
df['word_count'] = df['clean_text'].apply(lambda x: len(x.split()))
df['word_count']

#This creates a new column that counts the number of words in each cleaned text.
# Out:
# 0       37
# 1        9
# 2       50
# 3        8
# 4       14
#         ..
# 3838    12
# 3839    14
# 3840    30
# 3841    30
# 3842    12
# Name: word_count, Length: 3843, dtype: int64

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# ## count plot

# %%
sns.countplot(x='task_1', data=df,palette='bwr')
plt.title("Task_1 Distribution")
plt.show()

#“This plot shows how many text samples belong to each label category.”
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18496\2115206760.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='task_1', data=df,palette='bwr')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='task_1', y='word_count', data=df,palette='viridis')
plt.title("Word Count vs Task_1")
plt.show()

#The boxplot shows how word counts differ between offensive and non-offensive texts.
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18044\1468312485.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='task_1', y='word_count', data=df,palette='viridis')

# %% [markdown]
# # Histogram

# %%
sns.histplot(df['text_length'])
plt.title("Text Length Distribution")
plt.show()

#“The histogram shows that most texts are short to medium in length, with a right-skewed distribution and a few long outliers.”
